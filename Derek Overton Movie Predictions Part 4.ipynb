# %% [markdown]
# # **Movie Predictions Part 4**

# %% [markdown]
# **Name:** **Derek Overton**
#
# **Date:** **3/15/2023**
#
# **Project: Movie Predictions Part 4**

# %% [markdown]
# # **Imports**

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gzip
import pymysql
pymysql.install_as_MySQLdb()
import scipy.stats as stats

# Additional Imports
import os, json, math, time
import tmdbsimple as tmdb
from tqdm.notebook import tqdm_notebook
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists
from sqlalchemy.types import *
from urllib.parse import quote_plus
from scipy import stats
import glob

# %% [markdown]
# # **Loading Data**

# %%
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['.ipynb_checkpoints',
#  'akas.csv.gz',
#  'basics.csv.gz',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'final_tmdb_data_2002.csv.gz',
#  'final_tmdb_data_2003.csv.gz',
#  'final_tmdb_data_2004.csv.gz',
#  'final_tmdb_data_2005.csv.gz',
#  'final_tmdb_data_2006.csv.gz',
#  'final_tmdb_data_2007.csv.gz',
#  'final_tmdb_data_2008.csv.gz',
#  'final_tmdb_data_2009.csv.gz',
#  'final_tmdb_data_2010.csv.gz',
#  'final_tmdb_data_2011.csv.gz',
#  'final_tmdb_data_2012.csv.gz',
#  'final_tmdb_data_2013.csv.gz',
#  'final_tmdb_data_2014.csv.gz',
#  'final_tmdb_data_2015.csv.gz',
#  'final_tmdb_data_2016.csv.gz',
#  'final_tmdb_data_2017.csv.gz',
#  'final_tmdb_data_2018.csv.gz',
#  'final_tmdb_data_2019.csv.gz',
#  'final_tmdb_data_2020.csv.gz',
#  'ratings.csv.gz',
#  'tmdb_api_results_2000.csv.gz',
#  'tmdb_api_results_2000.json',
#  'tmdb_api_results_2001.json',
#  'tmdb_api_results_2002.json',
#  'tmdb_api_results_2003.json',
#  'tmdb_api_results_2004.json',
#  'tmdb_api_results_2005.json',
#  'tmdb_api_results_2006.json',
#  'tmdb_api_results_2007.json',
#  'tmdb_api_results_2008.json',
#  'tmdb_api_results_2009.json',
#  'tmdb_api_results_2010.json',
#  'tmdb_api_results_2011.json',
#  'tmdb_api_results_2012.json',
#  'tmdb_api_results_2013.json',
#  'tmdb_api_results_2014.json',
#  'tmdb_api_results_2015.json',
#  'tmdb_api_results_2016.json',
#  'tmdb_api_results_2017.json',
#  'tmdb_api_results_2018.json',
#  'tmdb_api_results_2019.json',
#  'tmdb_api_results_2020.json',
#  'tmdb_api_results_2021.json',
#  'tmdb_api_results_2022.json',
#  'tmdb_results_combined.csv.gz']

# %%
# Import Basics
basics = pd.read_csv('Data/basics.csv.gz')

# %%
# Import Ratings
ratings = pd.read_csv('Data/ratings.csv.gz')

# %%
# Import Akas
akas = pd.read_csv('Data/akas.csv.gz')

# %%
# Import Tmdb
tmdb = pd.read_csv('Data/tmdb_results_combined.csv.gz')

# %% [markdown]
# # **Create Custom Functions**

# %%
def df_to_sql(df,primary=None):
    sql_schema = {key: None for key in df.columns}
    #Create schema to convert col.dtype to sql-types
    for col in df.columns:
       # print (f"{col} is type:{basics[col].dtype}")
        if df[col].dtype == "int64":
            sql_schema[col]=Integer()
        elif df[col].dtype == "float64":
            sql_schema[col]=Float()
        elif df[col].dtype == "object":
            sql_schema[col]=Text(df[col].fillna('').map(len).max()+1)
    if primary != None:
        #Change the primary key to type String(length=...)
        sql_schema[primary] = String(df[primary].fillna('').map(len).max()+1)
    return sql_schema

# %% [markdown]
# # **Creating MYSQL Database**

# %%
# Create connection string using credentials following this format
# connection = "dialect+driver://username:password@host:port/database"
connection_str = "mysql+pymysql://root:Biggykrs11!!@localhost/movie"

# %%
# Create the engine:
engine = create_engine(connection_str)

# %%
# Check if the database exists. If not, create it.
if database_exists(connection_str) == False:
  create_database(connection_str)
else:
  print('The database already exists')
# Out:
# The database already exists

# %%
# Check for database existance:
database_exists(connection_str)
# Out:
# True

# %% [markdown]
# # **Making Dataframe tables in MySQL Database**

# %% [markdown]
# ## **Basics**

# %%
#Check the dtypes of your dataframe: (df.dtypes).
basics.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult             int64
# startYear           int64
# endYear           float64
# runtimeMinutes      int64
# genres             object
# dtype: object

# %%
#Use custom function to convert to sql-ready
basics_schema = df_to_sql(basics,"tconst")
basics_schema
# Out:
# {'tconst': String(length=11),
#  'titleType': Text(length=6),
#  'primaryTitle': Text(length=243),
#  'originalTitle': Text(length=243),
#  'isAdult': Integer(),
#  'startYear': Integer(),
#  'endYear': Float(),
#  'runtimeMinutes': Integer(),
#  'genres': Text(length=30)}

# %%
# Save to sql with dtype and index=False
basics.to_sql('title_basics',engine,dtype=basics_schema,if_exists='replace',
              index=False)
# Out:
# 86012

# %%
#Run the query to ADD PRIMARY KEY
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
#Query the table and show first 5 rows
q = '''
SELECT *
FROM title_basics
Limit 5;
'''
pd.read_sql_query(q, engine)
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear endYear  \
# 0                             Kate & Leopold        0       2001    None
# 1  El tango del viudo y su espejo deformante        0       2020    None
# 2                 The Other Side of the Wind        0       2018    None
# 3                          The Naked Monster        0       2005    None
# 4                       Crime and Punishment        0       2002    None
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %% [markdown]
# ## **Ratings**

# %%
ratings.columns
# Out:
# Index(['tconst', 'averageRating', 'numVotes'], dtype='object')

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1959
# 1  tt0000002            5.8       263
# 2  tt0000005            6.2      2596
# 3  tt0000006            5.1       177
# 4  tt0000007            5.4       815

# %%
ratings['tconst'].unique()
# Out:
# array(['tt0000001', 'tt0000002', 'tt0000005', ..., 'tt9916348',
#        'tt9916362', 'tt9916428'], dtype=object)

# %%
#Create a ratings_id map by pairing the unique ratings with an incrementing integer
ratings_id = range(len(ratings['tconst'].unique()))
ratings_map = dict(zip(ratings['tconst'].unique(), ratings_id))
#Add ratings_id primary key column
ratings["id"] = ratings["tconst"].map(ratings_map)

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes  id
# 0  tt0000001            5.7      1959   0
# 1  tt0000002            5.8       263   1
# 2  tt0000005            6.2      2596   2
# 3  tt0000006            5.1       177   3
# 4  tt0000007            5.4       815   4

# %%
ratings_schema = df_to_sql(ratings)
ratings_schema
# Out:
# {'tconst': Text(length=11),
#  'averageRating': Float(),
#  'numVotes': Integer(),
#  'id': Integer()}

# %%
# Save to sql with dtype and index=False
ratings.to_sql('title_ratings',engine,dtype=ratings_schema,if_exists='replace',
              index=False)
# Out:
# 492147

# %%
#Run the query to ADD PRIMARY KEY
engine.execute('ALTER TABLE title_ratings ADD PRIMARY KEY (`id`);')

# %%
#Query the table and show first 5 rows
q = '''
SELECT *
FROM title_ratings
Limit 5;
'''
pd.read_sql_query(q, engine)
# Out:
#       tconst  averageRating  numVotes  id
# 0  tt0000001            5.7      1959   0
# 1  tt0000002            5.8       263   1
# 2  tt0000005            6.2      2596   2
# 3  tt0000006            5.1       177   3
# 4  tt0000007            5.4       815   4

# %% [markdown]
# ## **Title_Genres**

# %%
## create a col with a list of genres
basics['genres_split'] = basics['genres'].str.split(',')
basics
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 86007  tt9914942     movie                             Life Without Sara Amat
# 86008  tt9915872     movie                               The Last White Witch
# 86009  tt9916170     movie                                      The Rehearsal
# 86010  tt9916190     movie                                          Safeguard
# 86011  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El tango del viudo y su espejo deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# 3                              The Naked Monster        0       2005      NaN
# 4                           Crime and Punishment        0       2002      NaN
# ...                                          ...      ...        ...      ...
# 86007                 La vida sense la Sara Amat        0       2019      NaN
# 86008                  My Girlfriend is a Wizard        0       2019      NaN
# 86009                                   O Ensaio        0       2019      NaN
# 86010                                  Safeguard        0       2020      NaN
# 86011                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres  \
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                 126                      Drama
# ...               ...                        ...
# 86007              74                      Drama
# 86008              97       Comedy,Drama,Fantasy
# 86009              51                      Drama
# 86010              95  Action,Adventure,Thriller
# 86011              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4                            [Drama]
# ...                              ...
# 86007                        [Drama]
# 86008       [Comedy, Drama, Fantasy]
# 86009                        [Drama]
# 86010  [Action, Adventure, Thriller]
# 86011               [Drama, History]
#
# [86012 rows x 10 columns]

# %%
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 86010  tt9916190     movie                                          Safeguard
# 86010  tt9916190     movie                                          Safeguard
# 86010  tt9916190     movie                                          Safeguard
# 86011  tt9916362     movie                                              Coven
# 86011  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El tango del viudo y su espejo deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# ...                                          ...      ...        ...      ...
# 86010                                  Safeguard        0       2020      NaN
# 86010                                  Safeguard        0       2020      NaN
# 86010                                  Safeguard        0       2020      NaN
# 86011                                   Akelarre        0       2020      NaN
# 86011                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres genres_split
# 0                 118     Comedy,Fantasy,Romance       Comedy
# 0                 118     Comedy,Fantasy,Romance      Fantasy
# 0                 118     Comedy,Fantasy,Romance      Romance
# 1                  70                      Drama        Drama
# 2                 122                      Drama        Drama
# ...               ...                        ...          ...
# 86010              95  Action,Adventure,Thriller       Action
# 86010              95  Action,Adventure,Thriller    Adventure
# 86010              95  Action,Adventure,Thriller     Thriller
# 86011              92              Drama,History        Drama
# 86011              92              Drama,History      History
#
# [160621 rows x 10 columns]

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %%
## Save just tconst and genres_split as new df
title_genres = exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
## Make a dictionary with list of unique genres as the key and the new iteger id as values
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
basics['genres_split'] = basics['genres_split'].apply(lambda x: tuple(x))

# %%
## make new integer genre_id and drop string genres
basics['genre_id'] = basics['genres_split'].map(genre_map)
basics = basics.drop(columns='genres_split')

# %%
## Manaully make dataframe with named cols from the .keyd and .values
genre_lookup = pd.DataFrame ({'Genre_Name': genre_id_map.keys(),
                             'genre_ID':genre_id_map.values()})
genre_lookup.head()
# Out:
#   Genre_Name  genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
basics['int_index'] = range(len(basics))

# %%
## get max string length
max_str_len = basics['genres'].fillna('').map(len).max()

# %%
## Calculate max string lengths for object columns
key_len = basics['tconst'].fillna('').map(len).max()
title_len = basics['primaryTitle'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'endYear':Float(),
    'runtimeMinutes':Integer()}

# %%
# Save to sql with dtype and index=False
basics.to_sql('title_basics',engine,dtype=df_schema,if_exists='replace',index=False)
# Out:
# 86012

# %%
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
#Check the dtypes of your dataframe: (df.dtypes).
title_genres.columns
# Out:
# Index(['tconst', 'genres_split'], dtype='object')

# %%
#Use custom function to convert to sql-ready
title_genres_schema = df_to_sql(title_genres)
title_genres_schema
# Out:
# {'tconst': Text(length=11), 'genres_split': Text(length=11)}

# %%
# Save to sql with dtype and index=False
title_genres.to_sql('title_genres',engine,dtype=title_genres_schema,if_exists='replace',
              index=False)
# Out:
# 160621

# %%
#Query the table and show first 5 rows
q = '''
SELECT *
FROM title_genres
Limit 5;
'''
pd.read_sql_query(q, engine)
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 1  tt0035423      Fantasy
# 2  tt0035423      Romance
# 3  tt0062336        Drama
# 4  tt0069049        Drama

# %% [markdown]
# ## **Genres**

# %%
genres = pd.DataFrame(basics)

# %%
genres.columns
# Out:
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres', 'genre_id',
#        'int_index'],
#       dtype='object')

# %%
#Use custom function to convert to sql-ready
genres_schema = df_to_sql(genres)
genres_schema
# Out:
# {'tconst': Text(length=11),
#  'titleType': Text(length=6),
#  'primaryTitle': Text(length=243),
#  'originalTitle': Text(length=243),
#  'isAdult': Integer(),
#  'startYear': Integer(),
#  'endYear': Float(),
#  'runtimeMinutes': Integer(),
#  'genres': Text(length=30),
#  'genre_id': Float(),
#  'int_index': Integer()}

# %%
# Save to sql with dtype and index=False
genres.to_sql('genres',engine,dtype=genres_schema,if_exists='replace',
              index=False)
# Out:
# 86012

# %%
#Query the table and show first 5 rows
q = '''
SELECT *
FROM genres
Limit 5;
'''
pd.read_sql_query(q, engine)
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear endYear  \
# 0                             Kate & Leopold        0       2001    None
# 1  El tango del viudo y su espejo deformante        0       2020    None
# 2                 The Other Side of the Wind        0       2018    None
# 3                          The Naked Monster        0       2005    None
# 4                       Crime and Punishment        0       2002    None
#
#    runtimeMinutes                  genres genre_id  int_index
# 0             118  Comedy,Fantasy,Romance     None          0
# 1              70                   Drama     None          1
# 2             122                   Drama     None          2
# 3             100    Comedy,Horror,Sci-Fi     None          3
# 4             126                   Drama     None          4

# %% [markdown]
# ## **TMBD Data**

# %%
tmdb.head()
# Out:
#      imdb_id  adult                     backdrop_path  \
# 0  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 1  tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 2  tt0120630    0.0  /t7aJ7hqsMLEoqBJk7yAXxcAVvcz.jpg
# 3  tt0120753    0.0  /3vUkQpnwbsFEQlMh9EORpvKJfpo.jpg
# 4  tt0120755    0.0  /24DZfupDlhXeTchmcOkoGRhP5Vg.jpg
#
#                                belongs_to_collection       budget  \
# 0                                                NaN     150000.0
# 1                                                NaN     120000.0
# 2  {'id': 718551, 'name': 'Chicken Run Collection...   45000000.0
# 3                                                NaN    8000000.0
# 4  {'id': 87359, 'name': 'Mission: Impossible Col...  125000000.0
#
#                                               genres homepage       id  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN    843.0
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...      NaN  19085.0
# 2  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...      NaN   7443.0
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN    318.0
# 4  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      NaN    955.0
#
#   original_language            original_title  ...      revenue  runtime  \
# 0                cn                      花樣年華  ...   12854953.0     99.0
# 1                en                    Vulgar  ...      14904.0     87.0
# 2                en               Chicken Run  ...  224834564.0     84.0
# 3                en  The Million Dollar Hotel  ...     105983.0    122.0
# 4                en    Mission: Impossible II  ...  546388105.0    123.0
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  \
# 0  Feel the heat, keep the feeling burning, let t...
# 1   Everyone loves a clown... some more than others.
# 2  This ain't no chick flick. It's poultry in mot...
# 3                    Everyone has something to hide.
# 4                       Expect the impossible again.
#
#                       title  video  vote_average vote_count certification
# 0      In the Mood for Love    0.0         8.115     2133.0            PG
# 1                    Vulgar    0.0         5.500       44.0             R
# 2               Chicken Run    0.0         6.740     4293.0             G
# 3  The Million Dollar Hotel    0.0         5.900      270.0             R
# 4    Mission: Impossible II    0.0         6.112     5657.0         PG-13
#
# [5 rows x 26 columns]

# %%
tmdb.columns
# Out:
# Index(['imdb_id', 'adult', 'backdrop_path', 'belongs_to_collection', 'budget',
#        'genres', 'homepage', 'id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'certification'],
#       dtype='object')

# %%
#You only need to keep the imdb_id, revenue, budget, and certification columns
tmdb_req = tmdb[["imdb_id","revenue","budget","certification"]]

# %%
#Use custom function to convert to sql-ready
tmdb_schema = df_to_sql(tmdb_req,"imdb_id")
tmdb_schema
# Out:
# {'imdb_id': String(length=11),
#  'revenue': Float(),
#  'budget': Float(),
#  'certification': Text(length=6)}

# %%
# Save to sql with dtype and index=False
tmdb_req.to_sql('tmdb_data',engine,dtype=tmdb_schema,if_exists='replace',
              index=False)
# Out:
# 1810

# %%
#Run the query to ADD PRIMARY KEY
engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')

# %%
#Query the table and show first 5 rows
q = '''
SELECT *
FROM tmdb_data
Limit 5;
'''
pd.read_sql_query(q, engine)
# Out:
#      imdb_id      revenue      budget certification
# 0  tt0035423   76019000.0  48000000.0         PG-13
# 1  tt0118589    5271670.0  22000000.0         PG-13
# 2  tt0118694   12855000.0    150000.0            PG
# 3  tt0120467      14904.0    120000.0             R
# 4  tt0120630  224835000.0  45000000.0             G

# %% [markdown]
# # **Movie Project Part Four**

# %% [markdown]
# ## **Hypothesis Testing**

# %% [markdown]
# **The stakeholder's first question is: does the MPAA rating of a movie (G/PG/PG-13/R) affect how much revenue the movie generates?**

# %% [markdown]
# - **Null Hypothesis:** The rating of a movie does not have a significant affect on how much revenue the movie generates.
#
# - **Alternate Hypothesis:** The rating of a movie does have a significant affect on how much revenue the movie generates.

# %%
q = "Data/tmdb_results_combined.csv.gz"
tmdb_results_combined = glob.glob(q)
# Showing the first 5
tmdb_results_combined[:5]
# Out:
# ['Data/tmdb_results_combined.csv.gz']

# %%
## Loading all files as df and appending to a list
df_list = []
for file in tmdb_results_combined:
    tmdb_df = pd.read_csv(file, index_col=0)
    df_list.append(tmdb_df)
    
## Concatenating the list of dfs into 1 combined
df_combined = pd.concat(df_list)
df_combined
# Out:
#            adult                     backdrop_path  \
# imdb_id
# tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# tt0120630    0.0  /t7aJ7hqsMLEoqBJk7yAXxcAVvcz.jpg
# tt0120753    0.0  /3vUkQpnwbsFEQlMh9EORpvKJfpo.jpg
# tt0120755    0.0  /24DZfupDlhXeTchmcOkoGRhP5Vg.jpg
# ...          ...                               ...
# tt9735462    0.0  /18diCYWCxODOpeJNV89hoPyobxj.jpg
# tt9770150    0.0  /563sRDK3rZS31TXCdTY4lfcwrNK.jpg
# tt9839038    0.0  /gq9FvopuQeGs6TKljGghefC14uD.jpg
# tt9877170    0.0  /3e46k8KPCs1N7luAqNDFZFzrbbE.jpg
# tt9883996    0.0  /wkaKu3gwAcw3n1mqfFmwNfPGasX.jpg
#
#                                        belongs_to_collection       budget  \
# imdb_id
# tt0118694                                                NaN     150000.0
# tt0120467                                                NaN     120000.0
# tt0120630  {'id': 718551, 'name': 'Chicken Run Collection...   45000000.0
# tt0120753                                                NaN    8000000.0
# tt0120755  {'id': 87359, 'name': 'Mission: Impossible Col...  125000000.0
# ...                                                      ...          ...
# tt9735462                                                NaN   25900000.0
# tt9770150                                                NaN    5000000.0
# tt9839038  {'id': 723457, 'name': 'Jim Button Collection'...   20000000.0
# tt9877170                                                NaN    7907534.0
# tt9883996                                                NaN   20000000.0
#
#                                                       genres  \
# imdb_id
# tt0118694  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# tt0120467  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# tt0120630  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# tt0120753  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# tt0120755  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ...                                                      ...
# tt9735462  [{'id': 10402, 'name': 'Music'}, {'id': 35, 'n...
# tt9770150                      [{'id': 18, 'name': 'Drama'}]
# tt9839038  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# tt9877170  [{'id': 10749, 'name': 'Romance'}, {'id': 28, ...
# tt9883996  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                                 homepage        id  \
# imdb_id
# tt0118694                                            NaN     843.0
# tt0120467                                            NaN   19085.0
# tt0120630                                            NaN    7443.0
# tt0120753                                            NaN     318.0
# tt0120755                                            NaN     955.0
# ...                                                  ...       ...
# tt9735462                                            NaN  498402.0
# tt9770150  https://www.searchlightpictures.com/nomadland  581734.0
# tt9839038                                            NaN  616180.0
# tt9877170                                            NaN  661043.0
# tt9883996    https://bleeckerstreetmedia.com/dream-horse  603206.0
#
#           original_language              original_title  \
# imdb_id
# tt0118694                cn                        花樣年華
# tt0120467                en                      Vulgar
# tt0120630                en                 Chicken Run
# tt0120753                en    The Million Dollar Hotel
# tt0120755                en      Mission: Impossible II
# ...                     ...                         ...
# tt9735462                fr                       Aline
# tt9770150                en                   Nomadland
# tt9839038                de  Jim Knopf und die Wilde 13
# tt9877170                hi                        मलंग
# tt9883996                en                 Dream Horse
#
#                                                     overview  ...  \
# imdb_id                                                       ...
# tt0118694  Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...  ...
# tt0120467  Vulgar is about a man who is a children's clow...  ...
# tt0120630  Having been hopelessly repressed and facing ev...  ...
# tt0120753  The Million Dollar Hotel starts with a jump fr...  ...
# tt0120755  With computer genius Luther Stickell at his si...  ...
# ...                                                      ...  ...
# tt9735462  A fictionalized biopic of Aline Dieu, a multit...  ...
# tt9770150  A woman in her sixties embarks on a journey th...  ...
# tt9839038  A year has gone by since Jim Button and his be...  ...
# tt9877170  Advait visits Goa where he meets Sara, a free-...  ...
# tt9883996  The inspiring true story of Dream Alliance, an...  ...
#
#                revenue runtime  \
# imdb_id
# tt0118694   12854953.0    99.0
# tt0120467      14904.0    87.0
# tt0120630  224834564.0    84.0
# tt0120753     105983.0   122.0
# tt0120755  546388105.0   123.0
# ...                ...     ...
# tt9735462   11131254.0   126.0
# tt9770150   14784114.0   108.0
# tt9839038    6700000.0   110.0
# tt9877170   11136444.0   135.0
# tt9883996    6435260.0   113.0
#
#                                             spoken_languages    status  \
# imdb_id
# tt0118694  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# tt0120467  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt0120630  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt0120753  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt0120755  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                      ...       ...
# tt9735462  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt9770150  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt9839038  [{'english_name': 'German', 'iso_639_1': 'de',...  Released
# tt9877170  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# tt9883996  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                                      tagline  \
# imdb_id
# tt0118694  Feel the heat, keep the feeling burning, let t...
# tt0120467   Everyone loves a clown... some more than others.
# tt0120630  This ain't no chick flick. It's poultry in mot...
# tt0120753                    Everyone has something to hide.
# tt0120755                       Expect the impossible again.
# ...                                                      ...
# tt9735462  A fiction freely inspired by the life of Célin...
# tt9770150                             See you down the road.
# tt9839038                                                NaN
# tt9877170                                Unleash The Madness
# tt9883996                                  Hearts will race.
#
#                                 title  video vote_average vote_count  \
# imdb_id
# tt0118694        In the Mood for Love    0.0        8.115     2133.0
# tt0120467                      Vulgar    0.0        5.500       44.0
# tt0120630                 Chicken Run    0.0        6.740     4293.0
# tt0120753    The Million Dollar Hotel    0.0        5.900      270.0
# tt0120755      Mission: Impossible II    0.0        6.112     5657.0
# ...                               ...    ...          ...        ...
# tt9735462                       Aline    0.0        6.827      269.0
# tt9770150                   Nomadland    0.0        7.261     2570.0
# tt9839038  Jim Button and the Wild 13    0.0        6.200       30.0
# tt9877170                      Malang    0.0        7.256       39.0
# tt9883996                 Dream Horse    0.0        7.101       89.0
#
#           certification
# imdb_id
# tt0118694            PG
# tt0120467             R
# tt0120630             G
# tt0120753             R
# tt0120755         PG-13
# ...                 ...
# tt9735462         PG-13
# tt9770150             R
# tt9839038           NaN
# tt9877170           NaN
# tt9883996           NaN
#
# [1810 rows x 25 columns]

# %%
## Loading and Concatenating the list of dfs with 1 line
df_combined = pd.concat([pd.read_csv(file, index_col=0) for file in tmdb_results_combined])
df_combined
# Out:
#            adult                     backdrop_path  \
# imdb_id
# tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# tt0120630    0.0  /t7aJ7hqsMLEoqBJk7yAXxcAVvcz.jpg
# tt0120753    0.0  /3vUkQpnwbsFEQlMh9EORpvKJfpo.jpg
# tt0120755    0.0  /24DZfupDlhXeTchmcOkoGRhP5Vg.jpg
# ...          ...                               ...
# tt9735462    0.0  /18diCYWCxODOpeJNV89hoPyobxj.jpg
# tt9770150    0.0  /563sRDK3rZS31TXCdTY4lfcwrNK.jpg
# tt9839038    0.0  /gq9FvopuQeGs6TKljGghefC14uD.jpg
# tt9877170    0.0  /3e46k8KPCs1N7luAqNDFZFzrbbE.jpg
# tt9883996    0.0  /wkaKu3gwAcw3n1mqfFmwNfPGasX.jpg
#
#                                        belongs_to_collection       budget  \
# imdb_id
# tt0118694                                                NaN     150000.0
# tt0120467                                                NaN     120000.0
# tt0120630  {'id': 718551, 'name': 'Chicken Run Collection...   45000000.0
# tt0120753                                                NaN    8000000.0
# tt0120755  {'id': 87359, 'name': 'Mission: Impossible Col...  125000000.0
# ...                                                      ...          ...
# tt9735462                                                NaN   25900000.0
# tt9770150                                                NaN    5000000.0
# tt9839038  {'id': 723457, 'name': 'Jim Button Collection'...   20000000.0
# tt9877170                                                NaN    7907534.0
# tt9883996                                                NaN   20000000.0
#
#                                                       genres  \
# imdb_id
# tt0118694  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# tt0120467  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# tt0120630  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# tt0120753  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# tt0120755  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ...                                                      ...
# tt9735462  [{'id': 10402, 'name': 'Music'}, {'id': 35, 'n...
# tt9770150                      [{'id': 18, 'name': 'Drama'}]
# tt9839038  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# tt9877170  [{'id': 10749, 'name': 'Romance'}, {'id': 28, ...
# tt9883996  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                                 homepage        id  \
# imdb_id
# tt0118694                                            NaN     843.0
# tt0120467                                            NaN   19085.0
# tt0120630                                            NaN    7443.0
# tt0120753                                            NaN     318.0
# tt0120755                                            NaN     955.0
# ...                                                  ...       ...
# tt9735462                                            NaN  498402.0
# tt9770150  https://www.searchlightpictures.com/nomadland  581734.0
# tt9839038                                            NaN  616180.0
# tt9877170                                            NaN  661043.0
# tt9883996    https://bleeckerstreetmedia.com/dream-horse  603206.0
#
#           original_language              original_title  \
# imdb_id
# tt0118694                cn                        花樣年華
# tt0120467                en                      Vulgar
# tt0120630                en                 Chicken Run
# tt0120753                en    The Million Dollar Hotel
# tt0120755                en      Mission: Impossible II
# ...                     ...                         ...
# tt9735462                fr                       Aline
# tt9770150                en                   Nomadland
# tt9839038                de  Jim Knopf und die Wilde 13
# tt9877170                hi                        मलंग
# tt9883996                en                 Dream Horse
#
#                                                     overview  ...  \
# imdb_id                                                       ...
# tt0118694  Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...  ...
# tt0120467  Vulgar is about a man who is a children's clow...  ...
# tt0120630  Having been hopelessly repressed and facing ev...  ...
# tt0120753  The Million Dollar Hotel starts with a jump fr...  ...
# tt0120755  With computer genius Luther Stickell at his si...  ...
# ...                                                      ...  ...
# tt9735462  A fictionalized biopic of Aline Dieu, a multit...  ...
# tt9770150  A woman in her sixties embarks on a journey th...  ...
# tt9839038  A year has gone by since Jim Button and his be...  ...
# tt9877170  Advait visits Goa where he meets Sara, a free-...  ...
# tt9883996  The inspiring true story of Dream Alliance, an...  ...
#
#                revenue runtime  \
# imdb_id
# tt0118694   12854953.0    99.0
# tt0120467      14904.0    87.0
# tt0120630  224834564.0    84.0
# tt0120753     105983.0   122.0
# tt0120755  546388105.0   123.0
# ...                ...     ...
# tt9735462   11131254.0   126.0
# tt9770150   14784114.0   108.0
# tt9839038    6700000.0   110.0
# tt9877170   11136444.0   135.0
# tt9883996    6435260.0   113.0
#
#                                             spoken_languages    status  \
# imdb_id
# tt0118694  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# tt0120467  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt0120630  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt0120753  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt0120755  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                      ...       ...
# tt9735462  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt9770150  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt9839038  [{'english_name': 'German', 'iso_639_1': 'de',...  Released
# tt9877170  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# tt9883996  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                                      tagline  \
# imdb_id
# tt0118694  Feel the heat, keep the feeling burning, let t...
# tt0120467   Everyone loves a clown... some more than others.
# tt0120630  This ain't no chick flick. It's poultry in mot...
# tt0120753                    Everyone has something to hide.
# tt0120755                       Expect the impossible again.
# ...                                                      ...
# tt9735462  A fiction freely inspired by the life of Célin...
# tt9770150                             See you down the road.
# tt9839038                                                NaN
# tt9877170                                Unleash The Madness
# tt9883996                                  Hearts will race.
#
#                                 title  video vote_average vote_count  \
# imdb_id
# tt0118694        In the Mood for Love    0.0        8.115     2133.0
# tt0120467                      Vulgar    0.0        5.500       44.0
# tt0120630                 Chicken Run    0.0        6.740     4293.0
# tt0120753    The Million Dollar Hotel    0.0        5.900      270.0
# tt0120755      Mission: Impossible II    0.0        6.112     5657.0
# ...                               ...    ...          ...        ...
# tt9735462                       Aline    0.0        6.827      269.0
# tt9770150                   Nomadland    0.0        7.261     2570.0
# tt9839038  Jim Button and the Wild 13    0.0        6.200       30.0
# tt9877170                      Malang    0.0        7.256       39.0
# tt9883996                 Dream Horse    0.0        7.101       89.0
#
#           certification
# imdb_id
# tt0118694            PG
# tt0120467             R
# tt0120630             G
# tt0120753             R
# tt0120755         PG-13
# ...                 ...
# tt9735462         PG-13
# tt9770150             R
# tt9839038           NaN
# tt9877170           NaN
# tt9883996           NaN
#
# [1810 rows x 25 columns]

# %%
## Saving the final combined dataframe
final_fname ='Data/tmdb_results_combined.csv.gz'
df_combined.to_csv(final_fname, compression='gzip', index=False)

# %%
df_combined = pd.read_csv(final_fname)
df_combined
# Out:
#       adult                     backdrop_path  \
# 0       0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 1       0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 2       0.0  /t7aJ7hqsMLEoqBJk7yAXxcAVvcz.jpg
# 3       0.0  /3vUkQpnwbsFEQlMh9EORpvKJfpo.jpg
# 4       0.0  /24DZfupDlhXeTchmcOkoGRhP5Vg.jpg
# ...     ...                               ...
# 1805    0.0  /18diCYWCxODOpeJNV89hoPyobxj.jpg
# 1806    0.0  /563sRDK3rZS31TXCdTY4lfcwrNK.jpg
# 1807    0.0  /gq9FvopuQeGs6TKljGghefC14uD.jpg
# 1808    0.0  /3e46k8KPCs1N7luAqNDFZFzrbbE.jpg
# 1809    0.0  /wkaKu3gwAcw3n1mqfFmwNfPGasX.jpg
#
#                                   belongs_to_collection       budget  \
# 0                                                   NaN     150000.0
# 1                                                   NaN     120000.0
# 2     {'id': 718551, 'name': 'Chicken Run Collection...   45000000.0
# 3                                                   NaN    8000000.0
# 4     {'id': 87359, 'name': 'Mission: Impossible Col...  125000000.0
# ...                                                 ...          ...
# 1805                                                NaN   25900000.0
# 1806                                                NaN    5000000.0
# 1807  {'id': 723457, 'name': 'Jim Button Collection'...   20000000.0
# 1808                                                NaN    7907534.0
# 1809                                                NaN   20000000.0
#
#                                                  genres  \
# 0     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 1     [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 2     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 4     [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ...                                                 ...
# 1805  [{'id': 10402, 'name': 'Music'}, {'id': 35, 'n...
# 1806                      [{'id': 18, 'name': 'Drama'}]
# 1807  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 1808  [{'id': 10749, 'name': 'Romance'}, {'id': 28, ...
# 1809  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                            homepage        id  \
# 0                                               NaN     843.0
# 1                                               NaN   19085.0
# 2                                               NaN    7443.0
# 3                                               NaN     318.0
# 4                                               NaN     955.0
# ...                                             ...       ...
# 1805                                            NaN  498402.0
# 1806  https://www.searchlightpictures.com/nomadland  581734.0
# 1807                                            NaN  616180.0
# 1808                                            NaN  661043.0
# 1809    https://bleeckerstreetmedia.com/dream-horse  603206.0
#
#      original_language              original_title  \
# 0                   cn                        花樣年華
# 1                   en                      Vulgar
# 2                   en                 Chicken Run
# 3                   en    The Million Dollar Hotel
# 4                   en      Mission: Impossible II
# ...                ...                         ...
# 1805                fr                       Aline
# 1806                en                   Nomadland
# 1807                de  Jim Knopf und die Wilde 13
# 1808                hi                        मलंग
# 1809                en                 Dream Horse
#
#                                                overview  ...      revenue  \
# 0     Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...  ...   12854953.0
# 1     Vulgar is about a man who is a children's clow...  ...      14904.0
# 2     Having been hopelessly repressed and facing ev...  ...  224834564.0
# 3     The Million Dollar Hotel starts with a jump fr...  ...     105983.0
# 4     With computer genius Luther Stickell at his si...  ...  546388105.0
# ...                                                 ...  ...          ...
# 1805  A fictionalized biopic of Aline Dieu, a multit...  ...   11131254.0
# 1806  A woman in her sixties embarks on a journey th...  ...   14784114.0
# 1807  A year has gone by since Jim Button and his be...  ...    6700000.0
# 1808  Advait visits Goa where he meets Sara, a free-...  ...   11136444.0
# 1809  The inspiring true story of Dream Alliance, an...  ...    6435260.0
#
#      runtime                                   spoken_languages    status  \
# 0       99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 1       87.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2       84.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3      122.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4      123.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...      ...                                                ...       ...
# 1805   126.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1806   108.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1807   110.0  [{'english_name': 'German', 'iso_639_1': 'de',...  Released
# 1808   135.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 1809   113.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                                 tagline  \
# 0     Feel the heat, keep the feeling burning, let t...
# 1      Everyone loves a clown... some more than others.
# 2     This ain't no chick flick. It's poultry in mot...
# 3                       Everyone has something to hide.
# 4                          Expect the impossible again.
# ...                                                 ...
# 1805  A fiction freely inspired by the life of Célin...
# 1806                             See you down the road.
# 1807                                                NaN
# 1808                                Unleash The Madness
# 1809                                  Hearts will race.
#
#                            title  video vote_average vote_count certification
# 0           In the Mood for Love    0.0        8.115     2133.0            PG
# 1                         Vulgar    0.0        5.500       44.0             R
# 2                    Chicken Run    0.0        6.740     4293.0             G
# 3       The Million Dollar Hotel    0.0        5.900      270.0             R
# 4         Mission: Impossible II    0.0        6.112     5657.0         PG-13
# ...                          ...    ...          ...        ...           ...
# 1805                       Aline    0.0        6.827      269.0         PG-13
# 1806                   Nomadland    0.0        7.261     2570.0             R
# 1807  Jim Button and the Wild 13    0.0        6.200       30.0           NaN
# 1808                      Malang    0.0        7.256       39.0           NaN
# 1809                 Dream Horse    0.0        7.101       89.0           NaN
#
# [1810 rows x 25 columns]
